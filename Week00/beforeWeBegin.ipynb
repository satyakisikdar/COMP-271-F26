# %% [markdown]
# # COMP 271: Data Structures I
# ## Week 00: Before We Begin

# %% [markdown]
# Welcome to COMP 271! Over the next fifteen weeks we're going to spend a lot of time building things together: refactoring messy code into clean abstractions, implementing linked lists and hash tables from scratch, and arguing (politely) about the right way to test a piece of code. None of that goes well if our first real class period gets eaten by installation problems and syllabus questions nobody's had a chance to ask yet.
#
# So before Week 01, I'm asking you to work through the short checklist below. None of it is hard. All of it saves us time later. Check items off as you go, and bring anything unresolved to the first class.
#
# > Get the logistics out of the way now, so Week 01 can be about data structures, not debugging your setup.

# %% [markdown]
# ## Before Week 01 Checklist

# %% [markdown]
# ### 1. Refresh your foundations
#
# COMP 271 builds directly on COMP 170 and COMP 163. Before Week 01, take stock of both your programming fundamentals and the math notation we'll lean on for algorithm analysis.

# %% [markdown]
# **Programming fundamentals**
#
# - [ ] **Arrays / lists:** comfortable with indexing, slicing, and common list operations. [Practice on LeetCode](https://leetcode.com/problem-list/v1e7rvrd/) if you want a refresher.
# - [ ] **Loops:** [`for`](https://docs.python.org/3/reference/compound_stmts.html#for) and [`while`](https://docs.python.org/3/reference/compound_stmts.html#while)
# - [ ] **Conditionals:** [`if`](https://docs.python.org/3/reference/compound_stmts.html#if)
# - [ ] **Strings:** comfortable with common string operations. [Practice on LeetCode](https://leetcode.com/problem-list/v1ei9bm1/) if you want a refresher.
#
# Two references worth bookmarking now, since you'll come back to them all semester:
#
# - [Python Language Reference](https://docs.python.org/3/reference/index.html)
# - [Python Standard Library](https://docs.python.org/3/library/index.html)

# %% [markdown]
# **Math and notation, from COMP 163**
#
# Data structures and algorithm analysis lean on notation from COMP 163: number sets, quantifiers, set operations, and asymptotic notation. Before Week 01, review:
#
# - **Number sets:** $\mathbb N$, $\mathbb R$, and subset notation, for example $\mathbb R_{<0}$
# - **Function declarations:** $f:\mathbb N\rightarrow \mathbb R$
# - **Quantifiers:** $\exists$, $\forall$
# - **Set membership:** $c\in\mathbb R_{>0}$
# - **Set operations and relations:** $\cup$, $\cap$, $\times$, $\subset$, $\supset$
# - **Important functions:** $\log_2n$, $e^n$, $n!$, $\binom{n}{k}$
#
# With a bit of review, you should be able to read, decode, and understand expressions such as the formal definition of Big-O:
#
# $$
# \begin{aligned}
# &\text{Let } f,g : \mathbb{N} \to \mathbb{R}. \\
# &g(n) \in \mathcal{O}(f(n))
# \;\Longleftrightarrow\;
# \exists\, c \in \mathbb{R}_{>0},\ \exists\, n_0 \in \mathbb{N}
# \text{ such that} \\
# &\forall\, n \in \mathbb{N},\ n \ge n_0,\ g(n) \le cf(n).
# \end{aligned}
# $$
#
# Suggested reading, free with your @luc.edu login: the *Concerning Sets* and *Functions* chapters of Ronald T. Kneusel's *Math for Programming*, available through O'Reilly.

# %% [markdown]
# ### 2. Get your environment ready
#
# - [ ] Install **Python 3** on your own machine
# - [ ] Install an IDE. I recommend **[VS Code](https://code.visualstudio.com)**, but any editor that supports Python is fine if you're already comfortable with it, except **IDLE**, whose bare-bones interface lacks the debugging tools, multi-file project support, and terminal/git integration this course's assignments require
# - [ ] Make sure **no AI code-generation features are turned on** in your IDE (GitHub Copilot, Cursor Tab, Codeium, and similar). If you've already installed one of these extensions, disable or uninstall it for this course; see the syllabus's Generative AI Usage policy for why this matters. (This applies inside Codespaces too: check the Copilot toggle there as well.)
# - [ ] Optional but encouraged: run the sanity-check cell below to confirm your local Python setup actually works

# %% [markdown]
# **Optional sanity check.** If you have Python installed locally, run the cell below. You should see your Python version printed with no errors.

# %%
import sys

print("Hello, COMP 271!")
print(f"You're running Python {sys.version.split()[0]}")

# %% [markdown]
# ### 3. Confirm access to our course platforms
#
# - [ ] **Sakai**: log into the COMP 271, Section **003** site and read the Overview page
# - [ ] **GitHub account**: if you don't already have one, create a free account at [github.com](https://github.com). Pick a username you'd be comfortable putting on a résumé; this account can outlive the course. Tip: if you sign up (or add a verified email) with your @luc.edu address, GitHub upgrades your account to the free Student/Education tier, which includes some useful extras, though keep any Copilot-style AI code completion turned off for this course, per the policy above
# - [ ] **Course repository**: this is a **public** repo, so there's nothing to request or be invited to. Each week's folder is linked from Sakai/the syllabus as it becomes available; just navigate to the current week's folder to find materials. This week's folder, for example: [Week00](https://github.com/satyakisikdar/COMP-271-F26/tree/main/Week00). Get comfortable working with it using whichever of the options below fits you:

# %% [markdown]
# | Option | What it is | Good for | Setup |
# |---|---|---|---|
# | **A. Browse on GitHub.com** | Viewing files directly on the repo's web page | A quick peek at a file (reading, not running, code) | None |
# | **B. Clone locally: GitHub Desktop** | A GUI app that clones the repo and manages git for you with buttons instead of commands | A local Python + VS Code setup without touching the command line yet | Install [GitHub Desktop](https://desktop.github.com) |
# | **C. Clone locally: terminal (`git clone ...`)** | The command-line workflow: `clone`, `pull`, `add`, `commit`, `push` | The version of this skill that transfers to every other CS course and job. **This is the one I want you comfortable with by the end of the semester.** | `git` installed (usually pre-installed on Mac/Linux) |
# | **D. GitHub Codespaces** | A full browser-based dev environment tied to the repo: edit *and* run code, no local install | A **portable fallback**, not your primary environment (see the note below) | None beyond a GitHub account |
#
# - [ ] Get the course repo open through **at least one** of the options above
# - [ ] **Goal for the semester:** build real fluency with a local IDE and the terminal (options B/C). That's an important skill I want you to leave this course with. Don't let Codespaces (option D) become the only way you know how to code.

# %% [markdown]
# #### Step by step: getting started with git from the terminal
#
# This is the workflow I'd like everyone comfortable with by the end of the semester, and there's no reason not to start now:
#
# 1. **Check git is installed:** run `git --version` in your terminal. It's preinstalled on most Mac/Linux systems; on Windows, install [Git for Windows](https://git-scm.com/download/win), which also gives you Git Bash.
# 2. **Tell git who you are** (one-time setup):
#    ```
#    git config --global user.name "Your Name"
#    git config --global user.email "you@example.com"
#    ```
# 3. **Clone the course repo:**
#    ```
#    git clone <course-repo-url>
#    ```
#    This downloads the whole repo to your machine.
# 4. **Move into a week's folder:**
#    ```
#    cd course-repo-name/Week01
#    ```
# 5. **Pull new material as it's added** throughout the semester:
#    ```
#    git pull
#    ```
# 6. **For your own coursework**, create your own repository on github.com ("New repository"), then connect a local folder to it:
#    ```
#    git init
#    git remote add origin <your-repo-url>
#    git add .
#    git commit -m "Week 1 work"
#    git push -u origin main
#    ```

# %% [markdown]
# > **Why keep your own work on GitHub, not just on your machine?** Because your code lives on GitHub, you can open a Codespace against it from *any* machine you log into: your laptop dies, you're on a lab computer, whatever, and pick up exactly where you left off, no setup required. Think of Codespaces as that hassle-free, portable safety net.

# %% [markdown]
# ---
#
# That's it: five short sections, nothing complicated. Once every box is checked, you're ready for Week 01.
#
# See you in Cuneo 302.
#
# :)
